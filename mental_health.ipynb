# %% [markdown]
# ## Importing ML Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read the csv

# %%
dataset1 = pd.read_csv('Student Mental health.csv')
dataset = pd.read_csv('Student_Mental_health.csv')

# %%
dataset['cgpa'] = dataset1['What is your CGPA?']

# %%
dataset
# Out:
#      gender 0=female,1=male  Age              course  \
# 0                         0   18         Engineering
# 1                         1   21   Islamic education
# 2                         1   19                 BIT
# 3                         0   22                Laws
# 4                         1   23        Mathemathics
# ..                      ...  ...                 ...
# 96                        0   21                 BCS
# 97                        1   18         Engineering
# 98                        0   19            Nursing
# 99                        0   23    Pendidikan Islam
# 100                       1   20  Biomedical science
#
#     Your current year of Study  What is your Family income?  Major Incidence  \
# 0                       year 1                         15.0                0
# 1                       year 2                         14.0                0
# 2                       Year 1                         13.0                0
# ...

# %%
dataset.drop("course", axis='columns', inplace=True)

# %%
dataset
# Out:
#      gender 0=female,1=male  Age Your current year of Study  \
# 0                         0   18                     year 1
# 1                         1   21                     year 2
# 2                         1   19                     Year 1
# 3                         0   22                     year 3
# 4                         1   23                     year 4
# ..                      ...  ...                        ...
# 96                        0   21                     year 1
# 97                        1   18                     Year 2
# 98                        0   19                     Year 3
# 99                        0   23                     year 4
# 100                       1   20                     Year 2
#
#      What is your Family income?  Major Incidence  Depression score  \
# 0                           15.0                0                21
# 1                           14.0                0                 5
# ...

# %%
dataset['Depression'] = dataset1['Do you have Depression?']
dataset['Anxiety'] = dataset1['Do you have Anxiety?']
dataset['Panic'] = dataset1['Do you have Panic attack?']

# %%
dataset
# Out:
#      gender 0=female,1=male  Age Your current year of Study  \
# 0                         0   18                     year 1
# 1                         1   21                     year 2
# 2                         1   19                     Year 1
# 3                         0   22                     year 3
# 4                         1   23                     year 4
# ..                      ...  ...                        ...
# 96                        0   21                     year 1
# 97                        1   18                     Year 2
# 98                        0   19                     Year 3
# 99                        0   23                     year 4
# 100                       1   20                     Year 2
#
#      What is your Family income?  Major Incidence  Depression score  \
# 0                           15.0                0                21
# 1                           14.0                0                 5
# ...

# %%
drop_cols = ['Depression score','Anxiety Score','ADHD score']

dataset.drop(drop_cols, axis='columns', inplace=True)

# %%
dataset
# Out:
#      gender 0=female,1=male  Age Your current year of Study  \
# 0                         0   18                     year 1
# 1                         1   21                     year 2
# 2                         1   19                     Year 1
# 3                         0   22                     year 3
# 4                         1   23                     year 4
# ..                      ...  ...                        ...
# 96                        0   21                     year 1
# 97                        1   18                     Year 2
# 98                        0   19                     Year 3
# 99                        0   23                     year 4
# 100                       1   20                     Year 2
#
#      What is your Family income?  Major Incidence  doctor required  \
# 0                           15.0                0                0
# 1                           14.0                0                0
# ...

# %%
def convert_cgpa_range_to_midpoint(cgpa_range):
    range_values = cgpa_range.split('-')
    start_value = float(range_values[0])
    end_value = float(range_values[1])
    mid_point = ((start_value + end_value)/2)*2.5
    return mid_point

dataset['cgpa'] = dataset['cgpa'].apply(convert_cgpa_range_to_midpoint)

# %%
dataset
# Out:
#      gender 0=female,1=male  Age Your current year of Study  \
# 0                         0   18                     year 1
# 1                         1   21                     year 2
# 2                         1   19                     Year 1
# 3                         0   22                     year 3
# 4                         1   23                     year 4
# ..                      ...  ...                        ...
# 96                        0   21                     year 1
# 97                        1   18                     Year 2
# 98                        0   19                     Year 3
# 99                        0   23                     year 4
# 100                       1   20                     Year 2
#
#      What is your Family income?  Major Incidence  doctor required    cgpa  \
# 0                           15.0                0                0  8.1125
# 1                           14.0                0                0  8.1125
# ...

# %%
df = dataset
df
# Out:
#      gender 0=female,1=male  Age Your current year of Study  \
# 0                         0   18                     year 1
# 1                         1   21                     year 2
# 2                         1   19                     Year 1
# 3                         0   22                     year 3
# 4                         1   23                     year 4
# ..                      ...  ...                        ...
# 96                        0   21                     year 1
# 97                        1   18                     Year 2
# 98                        0   19                     Year 3
# 99                        0   23                     year 4
# 100                       1   20                     Year 2
#
#      What is your Family income?  Major Incidence  doctor required    cgpa  \
# 0                           15.0                0                0  8.1125
# 1                           14.0                0                0  8.1125
# ...

# %%
df
# Out:
#      gender 0=female,1=male  Age Your current year of Study  \
# 0                         0   18                     year 1
# 1                         1   21                     year 2
# 2                         1   19                     Year 1
# 3                         0   22                     year 3
# 4                         1   23                     year 4
# ..                      ...  ...                        ...
# 96                        0   21                     year 1
# 97                        1   18                     Year 2
# 98                        0   19                     Year 3
# 99                        0   23                     year 4
# 100                       1   20                     Year 2
#
#      What is your Family income?  Major Incidence  doctor required    cgpa  \
# 0                           15.0                0                0  8.1125
# 1                           14.0                0                0  8.1125
# ...

# %%
def changeyear(year):
    year_val = int(year[-1])
    return year_val

df['Your current year of Study'] = df['Your current year of Study'].apply(changeyear)

# %%
df
# Out:
#      gender 0=female,1=male  Age  Your current year of Study  \
# 0                         0   18                           1
# 1                         1   21                           2
# 2                         1   19                           1
# 3                         0   22                           3
# 4                         1   23                           4
# ..                      ...  ...                         ...
# 96                        0   21                           1
# 97                        1   18                           2
# 98                        0   19                           3
# 99                        0   23                           4
# 100                       1   20                           2
#
#      What is your Family income?  Major Incidence  doctor required    cgpa  \
# 0                           15.0                0                0  8.1125
# 1                           14.0                0                0  8.1125
# ...

# %%
def yesno(val):
    if val == "Yes":
        return 1
    elif val == "No":
        return 0

df['Depression'] = df['Depression'].apply(yesno)
df['Anxiety'] = df['Anxiety'].apply(yesno)
df['Panic'] = df['Panic'].apply(yesno)

# %%
def salarychange(salary):
    changed_salary = pow(salary,1.2)
    changed_salary = pow(changed_salary,1.4)
    return changed_salary

df['What is your Family income?'] = df['What is your Family income?'].apply(salarychange)

df
# Out:
#      gender 0=female,1=male  Age  Your current year of Study  \
# 0                         0   18                           1
# 1                         1   21                           2
# 2                         1   19                           1
# 3                         0   22                           3
# 4                         1   23                           4
# ..                      ...  ...                         ...
# 96                        0   21                           1
# 97                        1   18                           2
# 98                        0   19                           3
# 99                        0   23                           4
# 100                       1   20                           2
#
#      What is your Family income?  Major Incidence  doctor required    cgpa  \
# 0                      94.587406                0                0  8.1125
# 1                      84.235489                0                0  8.1125
# ...

# %%
def changesalary(salary):
    changed_salary = salary/80
    changed_salary = changed_salary*100000
    return changed_salary

df['What is your Family income?'] = df['What is your Family income?'].apply(changesalary)

df
# Out:
#      gender 0=female,1=male  Age  Your current year of Study  \
# 0                         0   18                           1
# 1                         1   21                           2
# 2                         1   19                           1
# 3                         0   22                           3
# 4                         1   23                           4
# ..                      ...  ...                         ...
# 96                        0   21                           1
# 97                        1   18                           2
# 98                        0   19                           3
# 99                        0   23                           4
# 100                       1   20                           2
#
#      What is your Family income?  Major Incidence  doctor required    cgpa  \
# 0                  118234.257455                0                0  8.1125
# 1                  105294.360907                0                0  8.1125
# ...

# %% [markdown]
# ## Select Relevant Columns and Form Dataframe

# %%
depression_score = df['Depression']
depression_score
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 96     0
# 97     1
# 98     1
# 99     0
# 100    0
# Name: Depression, Length: 101, dtype: int64

# %%
anxiety_score = df['Anxiety']
anxiety_score
# Out:
# 0      0
# 1      1
# 2      1
# 3      0
# 4      0
#       ..
# 96     1
# 97     1
# 98     0
# 99     0
# 100    0
# Name: Anxiety, Length: 101, dtype: int64

# %%
adhd_score = df['Panic']
adhd_score
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 96     0
# 97     0
# 98     1
# 99     0
# 100    0
# Name: Panic, Length: 101, dtype: int64

# %%
doctor_recommendment = df['doctor required']
doctor_recommendment
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      0
#       ..
# 96     0
# 97     0
# 98     0
# 99     0
# 100    0
# Name: doctor required, Length: 101, dtype: int64

# %%
colums_to_drop = ['Depression','Anxiety','Panic','doctor required']

# %%
df.drop(columns=colums_to_drop, axis='columns', inplace=True)

# %%
df
# Out:
#      gender 0=female,1=male  Age  Your current year of Study  \
# 0                         0   18                           1
# 1                         1   21                           2
# 2                         1   19                           1
# 3                         0   22                           3
# 4                         1   23                           4
# ..                      ...  ...                         ...
# 96                        0   21                           1
# 97                        1   18                           2
# 98                        0   19                           3
# 99                        0   23                           4
# 100                       1   20                           2
#
#      What is your Family income?  Major Incidence    cgpa
# 0                  118234.257455                0  8.1125
# 1                  105294.360907                0  8.1125
# ...

# %% [markdown]
# ## Feature Scaling

# %%
dataframe = df

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df = scaler.fit_transform(df)

# %%
import sklearn

# %%
from sklearn.model_selection import train_test_split

# %%
df_train1,df_test1,depression_score_train,depression_score_test =  train_test_split(df, depression_score, test_size=0.2, random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ## Model to test Depression

# %%
model1 = RandomForestClassifier()
model3 = RandomForestClassifier()
model2 = LogisticRegression()

# %%
voting_classifier_1 = VotingClassifier(estimators=[
    ('rf', model1),
    ('lr', model2),
    ('rf2', model3)
], voting='soft')

# %%
voting_classifier_1.fit(df_train1, depression_score_train)
# Out:
# VotingClassifier(estimators=[('rf', RandomForestClassifier()),
#                              ('lr', LogisticRegression()),
#                              ('rf2', RandomForestClassifier())],
#                  voting='soft')

# %%
voting_classifier_1.score(df_test1, depression_score_test)
# Out:
# 0.7142857142857143

# %% [markdown]
# ## Model to test Anxiety

# %%
df_train2,df_test2,anxiety_score_train,anxiety_score_test =  train_test_split(df, depression_score, test_size=0.2, random_state=1)

# %%
voting_classifier_2 = VotingClassifier(estimators=[
    ('rf', model1),
    ('lr', model2),
    ('rf3', model3)
], voting='soft')

# %%
voting_classifier_2.fit(df_train2, anxiety_score_train)
# Out:
# VotingClassifier(estimators=[('rf', RandomForestClassifier()),
#                              ('lr', LogisticRegression()),
#                              ('rf3', RandomForestClassifier())],
#                  voting='soft')

# %%
voting_classifier_2.score(df_test2, anxiety_score_test)
# Out:
# 0.7142857142857143

# %%
voting_classifier_2.predict_proba([[0,18,0,15.0,0,8.1125]])
# Out:
# array([[0.96155732, 0.03844268]])

# %% [markdown]
# ## Model to test ADHD

# %%
df_train3, df_test3, adhd_score_train, adhd_score_test = train_test_split(df, adhd_score, test_size=0.2, random_state=1)

# %%
model7 = LogisticRegression()

# %%
model7.fit(df_train3, adhd_score_train)
# Out:
# LogisticRegression()

# %%
model7.score(df_test3, adhd_score_test)
# Out:
# 0.8095238095238095

# %% [markdown]
# ## Model to test requirement to check doctor

# %%
model8 = LogisticRegression()

# %%
df_train4, df_test4, doctor_recommendment_train, doctor_recommendment_test = train_test_split(df, doctor_recommendment)

# %%
model8.fit(df_train4, doctor_recommendment_train)
# Out:
# LogisticRegression()

# %%
model8.score(df_test4, doctor_recommendment_test)
# Out:
# 0.8846153846153846

# %%
model8.predict_proba([[0,18,0,15.0,0,8.1125]])
# Out:
# array([[0.00790437, 0.99209563]])

# %%
model9 = RandomForestClassifier()

# %%
model9.fit(df_train4, doctor_recommendment_train)
# Out:
# RandomForestClassifier()

# %%
model9.score(df_test4, doctor_recommendment_test)
# Out:
# 0.9230769230769231

# %%
voting_classifier_4 = VotingClassifier(estimators=[
        ('rf', model8),
        ('lr', model9)
    ], voting='soft'
)

# %%
voting_classifier_4.fit(df_train4, doctor_recommendment_train)
# Out:
# VotingClassifier(estimators=[('rf', LogisticRegression()),
#                              ('lr', RandomForestClassifier())],
#                  voting='soft')

# %%
voting_classifier_4.score(df_test4, doctor_recommendment_test)
# Out:
# 0.9230769230769231

# %%
voting_classifier_4.predict_proba(scaler.transform([[1,23,4,12.4,0,8.1125]]))
# Out:
# /Users/aayushkaayushumar/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[0.98905406, 0.01094594]])

# %%
voting_classifier_4.predict_proba(scaler.transform([[0,18,0,15.0,0,8.1125]]))
# Out:
# /Users/aayushkaayushumar/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[0.83095879, 0.16904121]])

# %%
voting_classifier_4.predict_proba(scaler.transform([[1,19,1,13.0,0,8.1125]]))
# Out:
# /Users/aayushkaayushumar/anaconda3/lib/python3.11/site-packages/sklearn/base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[0.82028595, 0.17971405]])

# %%
import pickle

# %%
with open('scaler.pkl','wb') as f:
    pickle.dump(scaler,f)

# %%
with open('depression.pkl','wb') as f:
    pickle.dump(voting_classifier_1,f)

# %%
with open('anxiety.pkl','wb') as f:
    pickle.dump(voting_classifier_2,f)

# %%
with open('adhd.pkl','wb') as f:
    pickle.dump(model7,f)

# %%
with open('doctor.pkl','wb') as f:
    pickle.dump(voting_classifier_4,f)
